# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('Companyinfo_2000-2021.csv')
data
# Out:
#          gvkey  datadate   fyear indfmt consol popsrc datafmt   tic  \
# 0         1004  20000531  1999.0   INDL      C      D     STD   AIR
# 1         1004  20010531  2000.0   INDL      C      D     STD   AIR
# 2         1004  20020531  2001.0   INDL      C      D     STD   AIR
# 3         1004  20030531  2002.0   INDL      C      D     STD   AIR
# 4         1004  20040531  2003.0   INDL      C      D     STD   AIR
# ...        ...       ...     ...    ...    ...    ...     ...   ...
# 255401  345980  20151231  2015.0   INDL      C      D     STD  WISH
# 255402  345980  20161231  2016.0   INDL      C      D     STD  WISH
# 255403  345980  20171231  2017.0   INDL      C      D     STD  WISH
# 255404  345980  20181231  2018.0   INDL      C      D     STD  WISH
# 255405  345980  20191231  2019.0   INDL      C      D     STD  WISH
#
#                     conm curcd costat  \
# 0               AAR CORP   USD      A
# 1               AAR CORP   USD      A
# ...

# %%
company = data.tic.unique().tolist()
len(company)
# Out:
# 26547

# %%
company1 = data.conm.unique().tolist()
len(company1)
# Out:
# 26569

# %%
company[0]
# Out:
# 'AIR'

# %%
com_df = data[data.tic == 'AIR']
com_df = com_df.drop(columns= ['gvkey','datadate','indfmt','consol','popsrc','datafmt',
                                  'curcd','costat','fyrc','fyear'])
print(len(set(com_df.add1.tolist())) == 1)
#print(com_df.add1.unique)
# Out:
# True

# %%
con_move=[]
con_nmove=[]
for com in company:
    com_df = data[data.tic == com]
    com_df = com_df.drop(columns= ['gvkey','datadate','indfmt','consol','popsrc','datafmt',
                                  'curcd','costat','fyrc','fyear'])
    comn_list=[]
    comn_list= com_df.add1.unique().tolist()
    if len(comn_list) == 1:
        con_nmove.append(com)
    else:
        con_move.append(com)
    print(comn_list)
# Out:
# ['One AAR Place, 1100 North Wood Dale Road']
# ['101 Clark Street']
# ['13625 Technology Drive']
# ['155 Michael Drive']
# ['8 Westchester Plaza, Suite 112']
# ['440 Route 22 East, P.O. Box 1399']
# ['2300 One First Union Center']
# ['1900 AM Drive']
# ['920 Main St']
# ['1 Skyview Drive']
# ['700 Louisiana Street']
# ['14651 North Dallas Parkway, Suite 500']
# ['35 South Service Road, PO Box 6022']
# ['400 South El Camino Real, Suite 710']
# ['One AVX Boulevard']
# ['400 North 5th Street, PO Box 53999']
# ['256 West Data Drive']
# ['100 Abbott Park Road, Department 377 Building AP6A-1, Abbott']
# ['111 Duke Street, Suite 5000']
# ['1945 The Exchange, Suite 325']
# ['11 Royal Road']
# ['4 Tri Harbor Court']
# ['1301 5th Avenue, Suite 4000']
# ['55 City Centre Drive, Suite 800']
# ['30 South Road']
# ['N85 W12545 Westbrook Crossing']
# ['55 Walls Drive, Suite 201']
# ['2200 Kensington Court']
# ['P O Box: 2677']
# ['3100 Ocean Park Boulevard']
# ['540 Alder Drive']
# ...

# %%
print(len(con_move))
print(len(con_nmove))
con_move
# Out:
# 1
# 26546
# [nan]
