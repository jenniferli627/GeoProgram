# %%
import numpy as np
import pandas as pd

# %%
Companies = pd.read_csv("Companyinfo_2000-2021.csv")
Companies
# Out:
#          gvkey  datadate   fyear indfmt consol popsrc datafmt   tic  \
# 0         1004  19990531  1998.0   INDL      C      D     STD   AIR
# 1         1004  20000531  1999.0   INDL      C      D     STD   AIR
# 2         1004  20010531  2000.0   INDL      C      D     STD   AIR
# 3         1004  20020531  2001.0   INDL      C      D     STD   AIR
# 4         1004  20030531  2002.0   INDL      C      D     STD   AIR
# ...        ...       ...     ...    ...    ...    ...     ...   ...
# 269491  345980  20151231  2015.0   INDL      C      D     STD  WISH
# 269492  345980  20161231  2016.0   INDL      C      D     STD  WISH
# 269493  345980  20171231  2017.0   INDL      C      D     STD  WISH
# 269494  345980  20181231  2018.0   INDL      C      D     STD  WISH
# 269495  345980  20191231  2019.0   INDL      C      D     STD  WISH
#
#                     conm curcd costat  \
# 0               AAR CORP   USD      A
# 1               AAR CORP   USD      A
# ...

# %%
Companies = Companies.loc[(Companies['cyear'] >= 2000)&(Companies['fyrc'] != 0)]
Companies
# Out:
#          gvkey  datadate   fyear indfmt consol popsrc datafmt   tic  \
# 1         1004  20000531  1999.0   INDL      C      D     STD   AIR
# 2         1004  20010531  2000.0   INDL      C      D     STD   AIR
# 3         1004  20020531  2001.0   INDL      C      D     STD   AIR
# 4         1004  20030531  2002.0   INDL      C      D     STD   AIR
# 5         1004  20040531  2003.0   INDL      C      D     STD   AIR
# ...        ...       ...     ...    ...    ...    ...     ...   ...
# 269491  345980  20151231  2015.0   INDL      C      D     STD  WISH
# 269492  345980  20161231  2016.0   INDL      C      D     STD  WISH
# 269493  345980  20171231  2017.0   INDL      C      D     STD  WISH
# 269494  345980  20181231  2018.0   INDL      C      D     STD  WISH
# 269495  345980  20191231  2019.0   INDL      C      D     STD  WISH
#
#                     conm curcd costat  \
# 1               AAR CORP   USD      A
# 2               AAR CORP   USD      A
# ...

# %%
import geopandas
import geopy

# %%
Companies.loc[1,'add1']+ ', ' + Companies.loc[1,'city']
# Out:
# 'One AAR Place, 1100 North Wood Dale Road, Wood Dale'

# %%
from geopy import Nominatim

# %%
Companies.loc[1,'add1']+ ',' + Companies.loc[1,'city'] + ',USA'
# Out:
# 'One AAR Place, 1100 North Wood Dale Road,Wood Dale,USA'

# %%
locator = Nominatim(user_agent='myGeocoder')
location = locator.geocode(Companies.loc[1,'add1']+ ',' + Companies.loc[1,'city'] + ',USA')

# %%
print(location)
# Out:
# None

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-61f49d0f0feb> in <module>
# ----> 1 print('Latitude = {}, Longitude = {}'.format(location.latitude, location.longitude))
#
# AttributeError: 'NoneType' object has no attribute 'latitude'

# %%
locator = Nominatim(user_agent='myGeocoder')
location = locator.geocode('Champ de Mars, Paris, France')

# %%
print(location)
# Out:
# Champ de Mars, Rue Saint-Dominique, Quartier du Gros-Caillou, Paris 7e Arrondissement, Paris, Île-de-France, France métropolitaine, 75007, France

# %%
print('Latitude = {}, Longitude = {}'.format(location.latitude, location.longitude))
# Out:
# Latitude = 48.85614465, Longitude = 2.297820393322227

# %%
from geopy.extra.rate_limiter import RateLimiter

# 1 - conveneint function to delay between geocoding calls
geocode = RateLimiter(locator.geocode, min_delay_seconds=1)
# 2- - create location column
Companies['location'] = Companies['add1'].apply(geocode)
# 3 - create longitude, laatitude and altitude from location column (returns tuple)
Companies['point'] = Companies['location'].apply(lambda loc: tuple(loc.point) if loc else None)
# 4 - split point column into latitude, longitude and altitude columns
Companies[['latitude', 'longitude', 'altitude']] = pd.DataFrame(Companies['point'].tolist(), index=df.index)
# Out:
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('920 Main St',), **{}).
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 426, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Anaconda3\lib\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Anaconda3\lib\http\client.py", line 1332, in getresponse
#     response.begin()
#   File "C:\Anaconda3\lib\http\client.py", line 303, in begin
#     version, status, reason = self._read_status()
#   File "C:\Anaconda3\lib\http\client.py", line 264, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Anaconda3\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Anaconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
# ...
