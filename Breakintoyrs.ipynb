# %%
import numpy as np
import pandas as pd

# %%
companies = pd.read_csv('CompanyInfo_2000-2021_WithL_Final.csv')
companies
# Out:
#          gvkey  datadate  fyear indfmt consol popsrc datafmt   tic  \
# 0         1004  20000531   1999   INDL      C      D     STD   AIR
# 1         1004  20010531   2000   INDL      C      D     STD   AIR
# 2         1004  20020531   2001   INDL      C      D     STD   AIR
# 3         1004  20030531   2002   INDL      C      D     STD   AIR
# 4         1004  20040531   2003   INDL      C      D     STD   AIR
# ...        ...       ...    ...    ...    ...    ...     ...   ...
# 225754  345980  20151231   2015   INDL      C      D     STD  WISH
# 225755  345980  20161231   2016   INDL      C      D     STD  WISH
# 225756  345980  20171231   2017   INDL      C      D     STD  WISH
# 225757  345980  20181231   2018   INDL      C      D     STD  WISH
# 225758  345980  20191231   2019   INDL      C      D     STD  WISH
#
#                     conm curcd costat  \
# 0               AAR CORP   USD      A
# 1               AAR CORP   USD      A
# 2               AAR CORP   USD      A
# ...

# %%
companies = companies.drop(columns = ['gvkey', 'fyear','indfmt','consol','popsrc','datafmt','curcd',
                                     'costat','fyrc','datadate'])
companies
# Out:
#          tic              conm                                      add1  \
# 0        AIR          AAR CORP  One AAR Place, 1100 North Wood Dale Road
# 1        AIR          AAR CORP  One AAR Place, 1100 North Wood Dale Road
# 2        AIR          AAR CORP  One AAR Place, 1100 North Wood Dale Road
# 3        AIR          AAR CORP  One AAR Place, 1100 North Wood Dale Road
# 4        AIR          AAR CORP  One AAR Place, 1100 North Wood Dale Road
# ...      ...               ...                                       ...
# 225754  WISH  CONTEXTLOGIC INC            One Sansome Street, 40th Floor
# 225755  WISH  CONTEXTLOGIC INC            One Sansome Street, 40th Floor
# 225756  WISH  CONTEXTLOGIC INC            One Sansome Street, 40th Floor
# 225757  WISH  CONTEXTLOGIC INC            One Sansome Street, 40th Floor
# 225758  WISH  CONTEXTLOGIC INC            One Sansome Street, 40th Floor
#
#             addzip           city  cyear   longitude   latitude
# ...

# %%
companies['longitude'] = companies['longitude'].round(2)
companies['latitude'] = companies['latitude'].round(2)
companies
# Out:
#          tic              conm                                      add1  \
# 0        AIR          AAR CORP  One AAR Place, 1100 North Wood Dale Road
# 1        AIR          AAR CORP  One AAR Place, 1100 North Wood Dale Road
# 2        AIR          AAR CORP  One AAR Place, 1100 North Wood Dale Road
# 3        AIR          AAR CORP  One AAR Place, 1100 North Wood Dale Road
# 4        AIR          AAR CORP  One AAR Place, 1100 North Wood Dale Road
# ...      ...               ...                                       ...
# 225754  WISH  CONTEXTLOGIC INC            One Sansome Street, 40th Floor
# 225755  WISH  CONTEXTLOGIC INC            One Sansome Street, 40th Floor
# 225756  WISH  CONTEXTLOGIC INC            One Sansome Street, 40th Floor
# 225757  WISH  CONTEXTLOGIC INC            One Sansome Street, 40th Floor
# 225758  WISH  CONTEXTLOGIC INC            One Sansome Street, 40th Floor
#
#             addzip           city  cyear  longitude  latitude
# ...

# %%
years = companies.cyear.unique().tolist()

# %%
for yr in years:
    yr_df = pd.DataFrame(data= companies[companies.cyear == yr])
    yr_df.to_csv('companies_%s.csv'%yr)

# %%
PM2000 = pd.read_csv('PM25_NA_2000.csv')
PM2000
# Out:
#       Unnamed: 0  -137.99  -137.98  -137.97  -137.96  -137.95  -137.94  \
# 0          22.50      1.3      1.3      1.3      1.3      1.3      1.2
# 1          22.51      1.3      1.3      1.3      1.3      1.2      1.2
# 2          22.52      1.3      1.3      1.3      1.3      1.3      1.3
# 3          22.53      1.3      1.3      1.3      1.3      1.3      1.3
# 4          22.54      1.4      1.4      1.4      1.4      1.3      1.3
# ...          ...      ...      ...      ...      ...      ...      ...
# 4545       67.95   -999.9   -999.9   -999.9   -999.9   -999.9   -999.9
# 4546       67.96   -999.9   -999.9   -999.9   -999.9   -999.9   -999.9
# 4547       67.97   -999.9   -999.9   -999.9   -999.9   -999.9   -999.9
# 4548       67.98   -999.9   -999.9   -999.9   -999.9   -999.9   -999.9
# 4549       67.99   -999.9   -999.9   -999.9   -999.9   -999.9   -999.9
#
#       -137.93  -137.92  -137.91  ...  -45.09  -45.08  -45.07  -45.06  -45.05  \
# ...

# %%
for xi in range(0,9300):
    x=round(xi*0.01-137.99,2)
        x_list.append(x)

    for yi in range(0,4550):
        y=round(yi*0.01+22.50,2)

# %%
lang= PM2000.columns.tolist()
lang= lang[1:]
lati= PM2000['Unnamed: 0'].tolist()

# %%
t1 = float(companies.iloc[225757,6])
t2 = companies.iloc[225757,7]
print(t1,t2)
# Out:
# -122.4 37.8

# %%
lang
# Out:
# ['-137.99',
#  '-137.98',
#  '-137.97',
#  '-137.96',
#  '-137.95',
#  '-137.94',
#  '-137.93',
#  '-137.92',
#  '-137.91',
#  '-137.9',
#  '-137.89',
#  '-137.88',
#  '-137.87',
#  '-137.86',
#  '-137.85',
#  '-137.84',
#  '-137.83',
#  '-137.82',
#  '-137.81',
#  '-137.8',
#  '-137.79',
#  '-137.78',
#  '-137.77',
#  '-137.76',
#  '-137.75',
#  '-137.74',
#  '-137.73',
#  '-137.72',
#  '-137.71',
#  '-137.7',
#  '-137.69',
#  '-137.68',
#  '-137.67',
#  '-137.66',
#  '-137.65',
#  '-137.64',
#  '-137.63',
#  '-137.62',
#  '-137.61',
#  '-137.6',
#  '-137.59',
#  '-137.58',
#  '-137.57',
#  '-137.56',
#  '-137.55',
#  '-137.54',
#  '-137.53',
#  '-137.52',
#  '-137.51',
#  '-137.5',
#  '-137.49',
#  '-137.48',
#  '-137.47',
#  '-137.46',
#  '-137.45',
#  '-137.44',
#  '-137.43',
#  '-137.42',
#  '-137.41',
#  '-137.4',
#  '-137.39',
#  '-137.38',
#  '-137.37',
#  '-137.36',
#  '-137.35',
#  '-137.34',
#  '-137.33',
#  '-137.32',
#  '-137.31',
#  '-137.3',
#  '-137.29',
# ...

# %%
max(lang)
# Out:
# '-99.99'

# %%
p1=lang.index(t1)
p2=lati.index(t2)
print(PM2000.iloc[p1,p2])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-7d43e4c9916c> in <module>
# ----> 1 p1=lang.index(t1)
#       2 p2=lati.index(t2)
#       3 print(PM2000.iloc[p1,p2])
#
# ValueError: -122.4 is not in list

# %%
PM2000.iloc(10.61,56.30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-19462f4494fe> in <module>
# ----> 1 PM2000.iloc(10.61,56.30)
#
# TypeError: __call__() takes from 1 to 2 positional arguments but 3 were given
