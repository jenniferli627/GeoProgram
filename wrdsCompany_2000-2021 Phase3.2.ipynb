# %%
import numpy as np
import pandas as pd
import geopandas
import geopy

# %%
Companies = pd.read_csv("Companyinfo_2000-2021.csv")
Companies.to_csv ('Companyinfo_2000-2021.csv', index = False, header=True)
Location = pd.read_csv("Location_final.csv")
Location
Companies.reset_index(drop=True, inplace=True)
Location.reset_index(drop=True, inplace=True)

# %%
Companies
# Out:
#          gvkey  datadate   fyear indfmt consol popsrc datafmt   tic  \
# 0         1004  20000531  1999.0   INDL      C      D     STD   AIR
# 1         1004  20010531  2000.0   INDL      C      D     STD   AIR
# 2         1004  20020531  2001.0   INDL      C      D     STD   AIR
# 3         1004  20030531  2002.0   INDL      C      D     STD   AIR
# 4         1004  20040531  2003.0   INDL      C      D     STD   AIR
# ...        ...       ...     ...    ...    ...    ...     ...   ...
# 255401  345980  20151231  2015.0   INDL      C      D     STD  WISH
# 255402  345980  20161231  2016.0   INDL      C      D     STD  WISH
# 255403  345980  20171231  2017.0   INDL      C      D     STD  WISH
# 255404  345980  20181231  2018.0   INDL      C      D     STD  WISH
# 255405  345980  20191231  2019.0   INDL      C      D     STD  WISH
#
#                     conm curcd costat  \
# 0               AAR CORP   USD      A
# 1               AAR CORP   USD      A
# ...

# %%
Location
# Out:
#          tic   longitude   latitude
# 0      JALSQ  139.723678  35.626070
# 1       UDI.  -80.844257  35.223631
# 2       ACEE  -88.066005  43.171143
# 3       AIRT  -81.038442  35.544505
# 4       EGN1  -86.807429  33.520286
# ...      ...         ...        ...
# 26542  CSTPF  -87.001674  34.601979
# 26543    ACA  -96.800212  32.784463
# 26544   CTRM   33.047380  34.675145
# 26545   IMUX  -73.981481  40.758058
# 26546   WISH -122.401955  37.797070
#
# [26547 rows x 3 columns]

# %%
Companies = Companies.merge(Location, on = 'tic',how='outer')
Companies
# Out:
#          gvkey  datadate   fyear indfmt consol popsrc datafmt   tic  \
# 0         1004  20000531  1999.0   INDL      C      D     STD   AIR
# 1         1004  20010531  2000.0   INDL      C      D     STD   AIR
# 2         1004  20020531  2001.0   INDL      C      D     STD   AIR
# 3         1004  20030531  2002.0   INDL      C      D     STD   AIR
# 4         1004  20040531  2003.0   INDL      C      D     STD   AIR
# ...        ...       ...     ...    ...    ...    ...     ...   ...
# 255401  345980  20151231  2015.0   INDL      C      D     STD  WISH
# 255402  345980  20161231  2016.0   INDL      C      D     STD  WISH
# 255403  345980  20171231  2017.0   INDL      C      D     STD  WISH
# 255404  345980  20181231  2018.0   INDL      C      D     STD  WISH
# 255405  345980  20191231  2019.0   INDL      C      D     STD  WISH
#
#                     conm curcd costat  \
# 0               AAR CORP   USD      A
# 1               AAR CORP   USD      A
# ...

# %%
df1 = Companies[Companies['tic'].isna()]
df1
# Out:
#         gvkey  datadate   fyear indfmt consol popsrc datafmt  tic  \
# 50354   16134  20111231  2011.0   INDL      C      D     STD  NaN
# 50355   16134  20121231  2012.0   INDL      C      D     STD  NaN
# 50356   16134  20131231  2013.0   INDL      C      D     STD  NaN
# 50357   16134  20141231  2014.0   INDL      C      D     STD  NaN
# 50358   18647  20131231  2013.0   INDL      C      D     STD  NaN
# ...       ...       ...     ...    ...    ...    ...     ...  ...
# 50501  183188  20181231  2018.0   INDL      C      D     STD  NaN
# 50502  183188  20191231  2019.0   INDL      C      D     STD  NaN
# 50503  183188  20201231  2020.0   INDL      C      D     STD  NaN
# 50504  184982  20081231  2008.0   INDL      C      D     STD  NaN
# 50505  184982  20091231  2009.0   INDL      C      D     STD  NaN
#
#                                conm curcd costat  \
# 50354  NORTHWEST INTL HLTH PRP REIT   CAD      I
# 50355  NORTHWEST INTL HLTH PRP REIT   CAD      I
# ...

# %%
Companies_L =  pd.read_csv("Companyinfo_2000-2021_WithL.csv")
ETF_DF = pd.read_csv("etfs_details_type_fund_flow.csv")
ETF_DF
# Out:
#      Symbol                                           ETF Name Asset Class  \
# 0       SPY                                   SPDR S&P 500 ETF      Equity
# 1       IVV                           iShares Core S&P 500 ETF      Equity
# 2       VTI                    Vanguard Total Stock Market ETF      Equity
# 3       VOO                               Vanguard S&P 500 ETF      Equity
# 4       QQQ                                        Invesco QQQ      Equity
# ...     ...                                                ...         ...
# 1554   HLGE                     Hartford Longevity Economy ETF         NaN
# 1555   INMU        BlackRock Intermediate Muni Income Bond ETF         NaN
# 1556   FMAR        FT Cboe Vest U.S. Equity Buffer ETF - March         NaN
# 1557   YMAR  FT Cboe Vest International Equity Buffer ETF -...         NaN
# 1558    UMI              USCF Midstream Energy Income Fund ETF         NaN
#
#             Total Assets  YTD Price Change Avg. Daily Volume  \
# ...

# %%
ETF_list = ETF_DF['Symbol'].tolist()
ETF_list
# Out:
# ['SPY',
#  'IVV',
#  'VTI',
#  'VOO',
#  'QQQ',
#  'AGG',
#  'VTV',
#  'BND',
#  'VUG',
#  'IWM',
#  'IJR',
#  'IWF',
#  'IJH',
#  'VIG',
#  'IWD',
#  'VO',
#  'VB',
#  'VCIT',
#  'LQD',
#  'VGT',
#  'VCSH',
#  'XLF',
#  'XLK',
#  'ITOT',
#  'VNQ',
#  'VYM',
#  'BSV',
#  'IVW',
#  'USMV',
#  'DIA',
#  'SCHX',
#  'IWR',
#  'IWB',
#  'MBB',
#  'TIP',
#  'XLV',
#  'IGSB',
#  'RSP',
#  'VBR',
#  'XLE',
#  'VV',
#  'ARKK',
#  'IVE',
#  'MUB',
#  'HYG',
#  'SCHD',
#  'MDY',
#  'SHY',
#  'QUAL',
#  'XLI',
#  'SCHB',
#  'XLY',
#  'SDY',
#  'PFF',
#  'DVY',
#  'DGRO',
#  'SCHP',
#  'JPST',
#  'IWN',
#  'SHV',
#  'VGK',
#  'VXF',
#  'ESGU',
#  'SCHA',
#  'VBK',
#  'TLT',
#  'GOVT',
#  'IEF',
#  'IWP',
#  'BIV',
#  'VMBS',
#  'VLUE',
#  'VHT',
#  'MTUM',
#  'SCHG',
#  'VOE',
#  'IWS',
#  'XLC',
#  'BIL',
#  'VTIP',
#  'GSLC',
#  'IUSB',
#  'XLU',
#  'IWO',
#  'VTEB',
#  'IEI',
#  'XLP',
#  'FVD',
#  'IWV',
#  'TQQQ',
#  'IUSG',
#  'VGSH',
#  'IBB',
#  'VOT',
#  'SPYV',
#  'JNK',
#  'MGK',
# ...

# %%
#Removing undesired rows by tics 
Companies_L = Companies_L[~Companies_L.tic.isin(ETF_list)]
Companies_L 
#Removing undesired rows by string in conm
Strings = ['ETF','ETN','MUNI','TRUST','INCOME','ISHARES']
for item in Strings:
    Companies_L= Companies_L[~(Companies_L.conm.str.contains(item) & (~Companies_L.conm.str.contains('INC')))]
    Companies_L= Companies_L[~(Companies_L.conm.str.contains(item) & (~Companies_L.conm.str.contains('FD')))]
Companies_L
# Out:
#          gvkey  datadate  fyear indfmt consol popsrc datafmt   tic  \
# 0         1004  20000531   1999   INDL      C      D     STD   AIR
# 1         1004  20010531   2000   INDL      C      D     STD   AIR
# 2         1004  20020531   2001   INDL      C      D     STD   AIR
# 3         1004  20030531   2002   INDL      C      D     STD   AIR
# 4         1004  20040531   2003   INDL      C      D     STD   AIR
# ...        ...       ...    ...    ...    ...    ...     ...   ...
# 255400  345980  20151231   2015   INDL      C      D     STD  WISH
# 255401  345980  20161231   2016   INDL      C      D     STD  WISH
# 255402  345980  20171231   2017   INDL      C      D     STD  WISH
# 255403  345980  20181231   2018   INDL      C      D     STD  WISH
# 255404  345980  20191231   2019   INDL      C      D     STD  WISH
#
#                     conm curcd costat  \
# 0               AAR CORP   USD      A
# 1               AAR CORP   USD      A
# 2               AAR CORP   USD      A
# ...

# %%
Companies_L.to_csv ('CompanyInfo_2000-2021_WithL_Final.csv', index = False, header=True)

# %%
#trying GoogleMap api
import requests
api_key= 'AIzaSyB-u5un5f7s8EbUmyCGdH9DwdKuEkc1BU0'
address = '301 S. COLLEGE STREET'
params = {
    'key': api_key,
    'address': address
}
base_url = 'https://maps.googleapis.com/maps/api/geocode/json' 
response = requests.get(base_url,params = params).json()
response.keys()
# Out:
# dict_keys(['results', 'status'])

# %%
if response['status']== 'OK':
    geometry = response['results'][0]['geometry']
    lat = geometry['location']['lat']
    lng = geometry['location']['lng']
print(lat,lng)
# Out:
# 35.2246625 -80.84427289999999

# %%
Companies.to_csv ('CompanyInfo_2000-2021_WithL.csv', index = False, header=True)
